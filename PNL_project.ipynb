# %% [markdown]
# <a href="https://colab.research.google.com/github/joaofernandesw/text-to-speach/blob/main/PNL_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...

# %%
from gtts import gTTS

text_to_speach = "Hello! Whats your name?"

language = 'en'

gtts_object = gTTS(text = text_to_speach, lang = language, slow = False)

gtts_object.save('/content/gtts.wav')

# %%
from IPython.display import Audio

Audio('/content/gtts.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
